# %%
import requests

# %%
cik = "0000789019"  # MSFT
url = f"https://data.sec.gov/submissions/CIK{cik}.json"

data = requests.get(url, headers=HEADERS, timeout=30).json()

print("Recent filing count:", len(data["filings"]["recent"]["accessionNumber"]))
print("Historical files:")
for f in data["filings"].get("files", []):
    print(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 cik = "0000789019"  # MSFT
#       2 url = f"https://data.sec.gov/submissions/CIK{cik}.json"
# ----> 4 data = requests.get(url, headers=HEADERS, timeout=30).json()
#       6 print("Recent filing count:", len(data["filings"]["recent"]["accessionNumber"]))
#       7 print("Historical files:")
#
# NameError: name 'HEADERS' is not defined
